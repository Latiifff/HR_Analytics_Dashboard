# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTcf_9Aqfsw8dGjKk1thOrFWounIatbnoYN6aPHYmBhH52ydwwHfjoI3MY0xll-tM2Kxedr1-jE3p_f/pub?gid=765045789&single=true&output=csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df['ManagerID'].unique()
# Out:
# array([22.,  4., 20., 16., 39., 11., 10., 19., 12.,  7., 14., 18., nan,
#         3.,  2.,  1., 17.,  5., 21.,  6., 15., 13.,  9., 30.])

# %%
df[['ManagerID', 'ManagerName']].drop_duplicates()
# Out:
#      ManagerID         ManagerName
# 0         22.0      Michael Albert
# 1          4.0          Simon Roup
# 2         20.0      Kissy Sullivan
# 3         16.0        Elijiah Gray
# 4         39.0      Webster Butler
# 5         11.0            Amy Dunn
# 6         10.0     Alex Sweetwater
# 7         19.0       Ketsia Liebig
# 8         12.0      Brannon Miller
# 9          7.0        Peter Monroe
# 10        14.0       David Stanley
# 13        18.0       Kelley Spirea
# 19         NaN      Webster Butler
# 26         3.0  Brandon R. LeBlanc
# 27         2.0          Janet King
# 29         1.0  Brandon R. LeBlanc
# 32        17.0          John Smith
# 35         5.0     Jennifer Zamora
# 45        21.0       Lynn Daneault
# 48         6.0        Eric Dougall
# 60        15.0      Debra Houlihan
# 70        13.0    Brian Champaigne
# 97         9.0  Board of Directors
# 129       30.0      Michael Albert

# %%
df['ManagerID'].fillna(39, inplace=True)

# %%
df[['ManagerID', 'ManagerName']].drop_duplicates()
# Out:
#      ManagerID         ManagerName
# 0         22.0      Michael Albert
# 1          4.0          Simon Roup
# 2         20.0      Kissy Sullivan
# 3         16.0        Elijiah Gray
# 4         39.0      Webster Butler
# 5         11.0            Amy Dunn
# 6         10.0     Alex Sweetwater
# 7         19.0       Ketsia Liebig
# 8         12.0      Brannon Miller
# 9          7.0        Peter Monroe
# 10        14.0       David Stanley
# 13        18.0       Kelley Spirea
# 26         3.0  Brandon R. LeBlanc
# 27         2.0          Janet King
# 29         1.0  Brandon R. LeBlanc
# 32        17.0          John Smith
# 35         5.0     Jennifer Zamora
# 45        21.0       Lynn Daneault
# 48         6.0        Eric Dougall
# 60        15.0      Debra Houlihan
# 70        13.0    Brian Champaigne
# 97         9.0  Board of Directors
# 129       30.0      Michael Albert

# %%
df['DateofTermination'].unique()
# Out:
# array([nan, '6/16/2016', '9/24/2012', '9/6/2016', '1/12/2017',
#        '9/19/2016', '4/6/2017', '8/4/2017', '9/12/2015', '4/4/2014',
#        '2/19/2016', '8/7/2014', '6/15/2013', '8/2/2014', '11/15/2015',
#        '1/7/2013', '9/26/2011', '9/23/2016', '6/8/2016', '11/4/2015',
#        '6/6/2017', '9/27/2018', '2/25/2018', '6/5/2013', '5/17/2016',
#        '6/24/2013', '1/9/2013', '8/19/2018', '11/15/2016', '9/5/2015',
#        '6/25/2015', '3/15/2015', '5/30/2011', '1/11/2014', '10/31/2014',
#        '12/15/2015', '6/18/2013', '4/7/2012', '4/15/2015', '4/1/2013',
#        '4/29/2018', '4/1/2016', '4/24/2014', '6/4/2015', '1/9/2014',
#        '12/12/2015', '3/31/2014', '4/15/2013', '9/26/2018', '9/15/2016',
#        '11/14/2015', '9/26/2017', '8/19/2012', '11/11/2016', '9/4/2014',
#        '5/25/2016', '5/1/2018', '8/19/2013', '1/12/2014', '9/7/2015',
#        '5/1/2016', '12/28/2017', '9/15/2015', '10/25/2015', '2/4/2013',
# ...

# %%
df['DateofTermination'].fillna('31/12/9999', inplace=True)

# %%
df[['DateofTermination', 'TermReason']].drop_duplicates()
# Out:
#     DateofTermination              TermReason
# 0          31/12/9999       N/A-StillEmployed
# 1           6/16/2016           career change
# 2           9/24/2012                   hours
# 4            9/6/2016        return to school
# 10          1/12/2017        Another position
# ..                ...                     ...
# 301          9/7/2015                 unhappy
# 302         5/14/2012        Another position
# 303         6/27/2015  relocation out of area
# 304         2/21/2016                retiring
# 307         9/29/2015        Another position
#
# [105 rows x 2 columns]

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %%
from google.colab import files

# Download file after cleaning
df.to_csv('HR_Data_Clean.csv', index=False)
files.download('HR_Data_Clean.csv')

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...
